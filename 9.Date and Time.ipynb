# %%
import pandas as pd

# %%
pd.Timestamp.now()
# Out:
# Timestamp('2022-06-08 18:16:48.427405')

# %%
custom_timestamp = pd.Timestamp(year = 2024, month = 8, day = 12, minute = 34, second = 45, microsecond = 14532)

# %%
custom_timestamp.day_name()
# Out:
# 'Monday'

# %%
custom_timestamp.day_of_week
# Out:
# 0

# %%
custom_timestamp.dayofweek
# both methods are one and the same, dayofweek is an alias of day_of_week
# Out:
# 0

# %% [markdown]
# ##### Get the Number of days in the month

# %%
custom_timestamp.days_in_month
# Out:
# 31

# %% [markdown]
# ##### Check if Leap year

# %%
custom_timestamp.is_leap_year
# Out:
# True

# %% [markdown]
# ##### T0 check if it is a month start/end or quater end or a year end

# %%
print(custom_timestamp.is_month_end)
print(custom_timestamp.is_leap_year)
print(custom_timestamp.is_quarter_start)
# Out:
# False
# True
# False
