# %%
import pandas as pd

# %%
data_dictionary = [
    {"field_name": "user_id", "description": "Unique identifier for a user", "data_type": "Integer", "example": 1001, "source": "User Database"},
    {"field_name": "name", "description": "Full name of the user", "data_type": "String", "example": "John Doe", "source": "User Input"},
    {"field_name": "user_id", "description": "Unique identifier for a user", "data_type": "Integer", "example": 1001, "source": "User Database"},
    {"field_name": "email", "description": "User's email address", "data_type": "String", "example": "john@example.com", "source": "User Input"},
    {"field_name": "name", "description": "Full name of the user", "data_type": "String", "example": "John Doe", "source": "User Input"},
    {"field_name": "age", "description": "Age of the user", "data_type": "Integer", "example": 30, "source": "User Input"},
    {"field_name": "email", "description": "User's email address", "data_type": "String", "example": "john@example.com", "source": "User Input"}
]

# %%
df = pd.DataFrame(data_dictionary)
df
# Out:
#   field_name                   description data_type           example  \
# 0    user_id  Unique identifier for a user   Integer              1001
# 1       name         Full name of the user    String          John Doe
# 2    user_id  Unique identifier for a user   Integer              1001
# 3      email          User's email address    String  john@example.com
# 4       name         Full name of the user    String          John Doe
# 5        age               Age of the user   Integer                30
# 6      email          User's email address    String  john@example.com
#
#           source
# 0  User Database
# 1     User Input
# 2  User Database
# 3     User Input
# 4     User Input
# 5     User Input
# 6     User Input

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#   field_name                   description data_type           example  \
# 0    user_id  Unique identifier for a user   Integer              1001
# 1       name         Full name of the user    String          John Doe
# 3      email          User's email address    String  john@example.com
# 5        age               Age of the user   Integer                30
#
#           source
# 0  User Database
# 1     User Input
# 3     User Input
# 5     User Input

# %%
print(pd.__version__)
# Out:
# 3.0.3
