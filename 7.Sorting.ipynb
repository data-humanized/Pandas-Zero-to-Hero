# %%
data = {
    'Id':['S01','S02','S03','S04','S05'],
    'Student':['Amit','Steve','John','Virat','Rohit'],
    'Rank':[1,4,3,5,2],
    'Marks':[90,70,80,60,90]

}

# %%
import pandas as pd

# %%
df = pd.DataFrame(data)

# %%
sorted_data = df.sort_values(by = ['Marks','Rank'], ascending = [True,False])
sorted_data
# Out:
#     Id Student  Rank  Marks
# 3  S04   Virat     5     60
# 1  S02   Steve     4     70
# 2  S03    John     3     80
# 4  S05   Rohit     2     90
# 0  S01    Amit     1     90
