# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Catogerical Series in pandas

# %%
s = pd.Series(["p","q","p","s","q",'r'],dtype = 'category')

# %%
s
# Out:
# 0    p
# 1    q
# 2    p
# 3    s
# 4    q
# 5    r
# dtype: category
# Categories (4, str): ['p', 'q', 'r', 's']

# %% [markdown]
# # Catogerical Dataframe

# %%
df = pd.DataFrame({"Cat1":list("pqrs"),"cat2":list("pqrp"),"cat3":list("pqrp")},dtype ='category')

# %% [markdown]
# # Working with category
# ## Appending category

# %%
s = s.cat.add_categories('a')
print("Updated Categories \n",s)
# Out:
# Updated Categories
#  0    p
# 1    q
# 2    p
# 3    s
# 4    q
# 5    r
# dtype: category
# Categories (5, str): ['p', 'q', 'r', 's', 'a']

# %% [markdown]
# ## Remove category in pandas

# %%
s = s.cat.remove_categories('r')

# %%
s
# Out:
# 0      p
# 1      q
# 2      p
# 3      s
# 4      q
# 5    NaN
# dtype: category
# Categories (4, str): ['a', 'p', 'q', 's']
